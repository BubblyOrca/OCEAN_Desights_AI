# %%
import pandas as pd
from pandas import DataFrame

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

#import scikit-learn


import datetime

# %matplotlib inline

os.getcwd()
# Out:
# '/Users/jasminebrunson/Documents/Data-Science-Bank/Datasets'

# %%
os.chdir("Consumer Price Index")

# %% [markdown]
# ### Consumer Price Index DataFrames

# %%
df_annual = pd.read_csv("Consumer_Price_Index_Annually.csv")
df_annual.head(10)
# Out:
#                  DATAFLOW      MEASURE UNIT_MEASURE REF_AREA FREQ CPI_DIV  \
# 0  FCSA:DF_CPI_ANN(3.2.0)  CPI_INDEX21         INDX       AE    A     FUR
# 1  FCSA:DF_CPI_ANN(3.2.0)  CPI_INDEX21         INDX       AE    A     FUR
# 2  FCSA:DF_CPI_ANN(3.2.0)  CPI_INDEX21         INDX       AE    A     FUR
# 3  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
# 4  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
# 5  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
# 6  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
# 7  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
# 8  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
# 9  FCSA:DF_CPI_ANN(3.2.0)   CPI_ANNCHG      PERCENT       AE    A     TEX
#
#   SOURCE_DETAIL  TIME_PERIOD   OBS_VALUE  DECIMALS  OBS_STATUS  UNIT_MULT
# 0          FCSA         2021  100.000000         2         NaN        NaN
# ...

# %%
# Set plot style
sns.set_theme(style="darkgrid")

# Assuming df_annual is already loaded
# If not, replace this with your actual dataframe loading code
# df_annual = pd.read_csv('your_file.csv')

# Create the lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_annual, x="TIME_PERIOD", y="OBS_VALUE")

# Customize the plot
plt.title('Time Series Plot of OBS_VALUE over TIME_PERIOD')
plt.xlabel('TIME_PERIOD')
plt.ylabel('OBS_VALUE')
# Out:
# Text(0, 0.5, 'OBS_VALUE')

# %%
df_monthly = pd.read_csv("Consumer_Price_Index_Monthly.csv")
df_monthly.head()
# Out:
#              DATAFLOW     MEASURE UNIT_MEASURE REF_AREA FREQ CPI_DIV  \
# 0  FCSA:DF_CPI(3.2.0)  CPI_ANNCHG      PERCENT       AE    M     FUR
# 1  FCSA:DF_CPI(3.2.0)  CPI_ANNCHG      PERCENT       AE    M     FUR
# 2  FCSA:DF_CPI(3.2.0)  CPI_ANNCHG      PERCENT       AE    M     FUR
# 3  FCSA:DF_CPI(3.2.0)  CPI_ANNCHG      PERCENT       AE    M     FUR
# 4  FCSA:DF_CPI(3.2.0)  CPI_ANNCHG      PERCENT       AE    M     FUR
#
#   SOURCE_DETAIL TIME_PERIOD  OBS_VALUE  DECIMALS  OBS_STATUS  UNIT_MULT
# 0          FCSA     2009-01       7.25         2         NaN        NaN
# 1          FCSA     2009-02       3.87         2         NaN        NaN
# 2          FCSA     2009-03       4.70         2         NaN        NaN
# 3          FCSA     2009-04       1.90         2         NaN        NaN
# 4          FCSA     2009-05       5.25         2         NaN        NaN

# %%
# Set plot style
sns.set_theme(style="darkgrid", palette='deep')

# Assuming df_annual is already loaded
# If not, replace this with your actual dataframe loading code
# df_annual = pd.read_csv('your_file.csv')

# Create the lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_monthly, x="TIME_PERIOD", y="OBS_VALUE")

# Customize the plot
plt.title('Time Series Plot of OBS_VALUE over TIME_PERIOD')
plt.xlabel('TIME_PERIOD')
plt.ylabel('OBS_VALUE')
plt.tight_layout()

# %%
df_quarterly = pd.read_csv("Consumer_Price_Index_Quarterly.csv")
df_quarterly.head()
# Out:
#                DATAFLOW    MEASURE UNIT_MEASURE REF_AREA FREQ CPI_DIV  \
# 0  FCSA:DF_CPI_Q(3.2.0)  CPI_QCHNG      PERCENT       AE    Q     HOU
# 1  FCSA:DF_CPI_Q(3.2.0)  CPI_QCHNG      PERCENT       AE    Q     HOU
# 2  FCSA:DF_CPI_Q(3.2.0)  CPI_QCHNG      PERCENT       AE    Q     HOU
# 3  FCSA:DF_CPI_Q(3.2.0)  CPI_QCHNG      PERCENT       AE    Q     HOU
# 4  FCSA:DF_CPI_Q(3.2.0)  CPI_QCHNG      PERCENT       AE    Q     HOU
#
#   SOURCE_DETAIL TIME_PERIOD  OBS_VALUE  DECIMALS  OBS_STATUS  UNIT_MULT
# 0          FCSA     2022-Q1  -1.851788         2         NaN        NaN
# 1          FCSA     2022-Q2  -1.001258         2         NaN        NaN
# 2          FCSA     2022-Q3   0.119038         2         NaN        NaN
# 3          FCSA     2022-Q4   1.605925         2         NaN        NaN
# 4          FCSA     2023-Q1   2.451617         2         NaN        NaN

# %%
os.chdir("../")

# %%
os.chdir("Currency Strength")

# %%
df_CS = pd.read_csv("AED-USD.csv")
df_CS.head()
# Out:
#    Unnamed: 0      Open      High       Low     Close  Adj Close  Volume  \
# 0           0  0.272331  0.272368  0.272331  0.272368   0.272368       0
# 1           1  0.272413  0.272420  0.272331  0.272368   0.272368       0
# 2           2  0.272339  0.272368  0.272331  0.272368   0.272368       0
# 3           3  0.272346  0.272368  0.272331  0.272368   0.272368       0
# 4           4  0.272339  0.272346  0.272331  0.272346   0.272346       0
#
#          Date    Return
# 0  2003-12-01       NaN
# 1  2003-12-02  0.000000
# 2  2003-12-03  0.000000
# 3  2003-12-04  0.000000
# 4  2003-12-05 -0.008174

# %%
os.chdir("../")

# %%
os.chdir("Gross Domestic Product")

# %%
df_const = pd.read_csv("GDP_Quarterly_Constant_Prices.csv")
df_const.head()
# Out:
#                   DATAFLOW REF_AREA FREQ UNIT_MEASURE SOURCE_DETAIL MEASURE  \
# 0  FCSA:DF_QGDP_CON(1.8.0)       AE    Q       MILAED          FCSC     ELE
# 1  FCSA:DF_QGDP_CON(1.8.0)       AE    Q       MILAED          FCSC     ELE
# 2  FCSA:DF_QGDP_CON(1.8.0)       AE    Q       MILAED          FCSC     ELE
# 3  FCSA:DF_QGDP_CON(1.8.0)       AE    Q       MILAED          FCSC     ELE
# 4  FCSA:DF_QGDP_CON(1.8.0)       AE    Q       MILAED          FCSC     ELE
#
#   QUARTER QGDP_SYS QGDP_UNIT  TIME_PERIOD    OBS_VALUE  OBS_STATUS  UNIT_MULT  \
# 0      Q1      CON       VAL         2012  6029.460989         NaN        NaN
# 1      Q1      CON       VAL         2013  6516.431786         NaN        NaN
# 2      Q1      CON       VAL         2014  7282.519220         NaN        NaN
# 3      Q1      CON       VAL         2015  5581.622819         NaN        NaN
# 4      Q1      CON       VAL         2016  6507.318473         NaN        NaN
#
#    OBS_COMMENT  DECIMALS
# ...

# %%
df_curr = pd.read_csv("GDP_Quarterly_Current_Prices.csv")
df_curr.head()
# Out:
#                   DATAFLOW REF_AREA FREQ UNIT_MEASURE SOURCE_DETAIL MEASURE  \
# 0  FCSA:DF_QGDP_CUR(1.8.0)       AE    Q      PERCENT          FCSC     NFC
# 1  FCSA:DF_QGDP_CUR(1.8.0)       AE    Q      PERCENT          FCSC     NFC
# 2  FCSA:DF_QGDP_CUR(1.8.0)       AE    Q      PERCENT          FCSC     NFC
# 3  FCSA:DF_QGDP_CUR(1.8.0)       AE    Q      PERCENT          FCSC     NFC
# 4  FCSA:DF_QGDP_CUR(1.8.0)       AE    Q      PERCENT          FCSC     NFC
#
#   QUARTER QGDP_SYS  QGDP_UNIT  TIME_PERIOD  OBS_VALUE  OBS_STATUS  UNIT_MULT  \
# 0      Q3      CUR  GWTH_RATE         2013   4.355075         NaN        NaN
# 1      Q3      CUR  GWTH_RATE         2014   4.394883         NaN        NaN
# 2      Q3      CUR  GWTH_RATE         2015 -15.526115         NaN        NaN
# 3      Q3      CUR  GWTH_RATE         2016  -1.059347         NaN        NaN
# 4      Q3      CUR  GWTH_RATE         2017   3.219329         NaN        NaN
#
#    OBS_COMMENT  DECIMALS
# ...

# %%
os.chdir("../")

# %%
os.chdir("Population")

# %%
df_gen = pd.read_csv("Population_Estimates_and_Growth_by_Gender.csv")
df_gen.head()
# Out:
#              DATAFLOW MEASURE POP_IND UNIT_MEASURE REF_AREA FREQ GENDER  \
# 0  FCSA:DF_POP(2.7.0)     POP      _Z           PS       AE    A      M
# 1  FCSA:DF_POP(2.7.0)     POP      _Z           PS       AE    A      M
# 2  FCSA:DF_POP(2.7.0)     POP      _Z           PS       AE    A      M
# 3  FCSA:DF_POP(2.7.0)     POP      _Z           PS       AE    A      M
# 4  FCSA:DF_POP(2.7.0)     POP      _Z           PS       AE    A      M
#
#   SOURCE_DETAIL  TIME_PERIOD  OBS_VALUE  DECIMALS
# 0          FCSC         1970     149195       NaN
# 1          FCSC         1971     181473       NaN
# 2          FCSC         1972     221774       NaN
# 3          FCSC         1973     268398       NaN
# 4          FCSC         1974     322544       NaN

# %%
df_ind = pd.read_csv("Population_Indicators.csv")
df_ind.head()
# Out:
#                  DATAFLOW MEASURE POP_IND UNIT_MEASURE REF_AREA FREQ GENDER  \
# 0  FCSA:DF_POP_IND(2.7.0)  POPIND     MED        YEARS       AE    A     _Z
# 1  FCSA:DF_POP_IND(2.7.0)  POPIND     MED        YEARS       AE    A     _Z
# 2  FCSA:DF_POP_IND(2.7.0)  POPIND     CDR        RATIO       AE    A     _Z
# 3  FCSA:DF_POP_IND(2.7.0)  POPIND     CDR        RATIO       AE    A     _Z
# 4  FCSA:DF_POP_IND(2.7.0)  POPIND     LEB        YEARS       AE    A     _Z
#
#   SOURCE_DETAIL  TIME_PERIOD  OBS_VALUE  DECIMALS
# 0          FCSC         2019      31.30         1
# 1          FCSC         2020      32.80         1
# 2          FCSC         2019      20.37         1
# 3          FCSC         2020      17.90         1
# 4          FCSC         2019      79.90         1

# %%
os.chdir("../")

# %%
os.chdir("Rents & Transactions")

# %%
os.getcwd()
# Out:
# '/Users/jasminebrunson/Documents/Data-Science-Bank/Datasets/Rents & Transactions'

# %%
rents = pd.read_csv("rents.csv", sep=",", on_bad_lines='skip')
rents.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 rents = pd.read_csv("rents.csv", sep=",", on_bad_lines='skip')
#       2 rents.head()
#
# File /opt/homebrew/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df_tx = pd.read_csv("transactions.csv", sep=",", on_bad_lines='skip')
df_tx.head()

# %%
os.chdir("../")

# %%
os.chdir("Tourism")

# %%
hotel_reg = pd.read_csv("Guests_by_Hotel_Type_by_Region.csv")
hotel_reg.head()

# %%
hotel_rating = pd.read_csv("Hotel_Establishments_and_Rooms_by_Rating_Type.csv")
hotel_rating.head()

# %%
hotel_ind = pd.read_csv("Hotel_Establishments_Main_Indicators.csv")
hotel_ind.head()

# %%
os.chdir("../")

# %%
os.chdir("World Development Indicators")

# %%
world_dev_meta = pd.read_csv("Metadata_World_Development_Indicator.csv")
world_dev_meta.head()

# %%
world_dev_ind = pd.read_csv("World_Development_Indicator.csv", sep=",", on_bad_lines='skip') 
world_dev_ind.head()
